# %%
import pandas as pd 
rollers = pd.read_csv('rollercoasterdata.csv')
rollers.columns = rollers.columns.str.strip()
rollers.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Park</th>
#       <th>City/Region</th>
#       <th>City/State/Region</th>
#       <th>Country/Region</th>
#       <th>Geographic Region</th>
#       <th>Construction</th>
#       <th>Type</th>
#       <th>Status</th>
#       <th>Year/Date Opened</th>
#       <th>Height (feet)</th>
#       <th>Speed (mph)</th>
#       <th>Length (feet)</th>
#       <th>Inversions (YES or NO)</th>
#       <th>Number of Inversions</th>
#       <th>Drop (feet)</th>
#       <th>Duration (min:sec)</th>
#       <th>G Force</th>
#       <th>Vertical Angle (degrees)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10 Inversion Roller Coaster</td>
#       <td>Chimelong Paradise</td>
#       <td>Panyu</td>
#       <td>Guangzhou, Guangdong</td>
#       <td>China</td>
#       <td>Asia</td>
#       <td>Steel</td>
#       <td>Sit Down</td>
#       <td>Operating</td>
#       <td>2006.0</td>
#       <td>98.4</td>
#       <td>45.0</td>
#       <td>2788.8</td>
#       <td>YES</td>
#       <td>10.0</td>
#       <td>NaN</td>
#       <td>1:32</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Abismo</td>
#       <td>Parque de Atracciones de Madrid</td>
#       <td>Madrid</td>
#       <td>Madrid</td>
#       <td>Spain</td>
#       <td>Europe</td>
#       <td>Steel</td>
#       <td>Sit Down</td>
#       <td>Operating</td>
#       <td>2006.0</td>
#       <td>151.6</td>
#       <td>65.2</td>
#       <td>1476.4</td>
#       <td>YES</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>1:00</td>
#       <td>4</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Adrenaline Peak</td>
#       <td>Oaks Amusement Park</td>
#       <td>Portland</td>
#       <td>Oregon</td>
#       <td>United States</td>
#       <td>North America</td>
#       <td>Steel</td>
#       <td>Sit Down</td>
#       <td>Operating</td>
#       <td>2018.0</td>
#       <td>72</td>
#       <td>45.0</td>
#       <td>1050.0</td>
#       <td>YES</td>
#       <td>3.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>97.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Afterburn</td>
#       <td>Carowinds</td>
#       <td>Charlotte</td>
#       <td>North Carolina</td>
#       <td>United States</td>
#       <td>North America</td>
#       <td>Steel</td>
#       <td>Inverted</td>
#       <td>Operating</td>
#       <td>1999.0</td>
#       <td>113</td>
#       <td>62.0</td>
#       <td>2956.0</td>
#       <td>YES</td>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>2:47</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Alpengeist</td>
#       <td>Busch Gardens Williamsburg</td>
#       <td>Williamsburg</td>
#       <td>Virginia</td>
#       <td>United States</td>
#       <td>North America</td>
#       <td>Steel</td>
#       <td>Inverted</td>
#       <td>Operating</td>
#       <td>1997.0</td>
#       <td>195</td>
#       <td>67.0</td>
#       <td>3828.0</td>
#       <td>YES</td>
#       <td>6.0</td>
#       <td>170</td>
#       <td>3:10</td>
#       <td>3.7</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#rank the rollercoasters by spped and give them points based on their ranks 
rollers_speed = rollers.dropna(subset=["Speed (mph)"])
rollers['Speed Score'] = rollers_speed["Speed (mph)"].rank(ascending=True)
rollers_speed.sort_values(by="Speed (mph)", ascending = False)
rollers['Speed Score'].fillna(0, inplace = True)

#rank the rollercoasters by drops and give points based on their ranks 
rollers_drops = rollers.dropna(subset=["Drop (feet)"])
rollers['Drop Score'] = rollers_drops["Drop (feet)"].rank(ascending=True)
rollers_drops.sort_values(by="Drop (feet)", ascending = False)
rollers['Drop Score'].fillna(0, inplace = True)

#wood bonus
def bonus(construction):
    if construction=='wood':
        return 10
    elif construction=='steel':
        return 0
    else:
        return 0
rollers['Construction Bonus'] = rollers.Construction.apply(bonus)

#fill in / replace the blank Durationa will 0:00
rollers['Duration (min:sec)']=rollers['Duration (min:sec)'].fillna("0:00")
rollers['Duration (min:sec)']=rollers['Duration (min:sec)'].replace(" ", "0:00")
rollers['Duration (min:sec)']=pd.to_datetime(rollers['Duration (min:sec)'], format='%M:%S')
rollers.head()

#convert duration time into seconds
import time, datetime
def convert(t):
    return int(datetime.timedelta(minutes=t.minute, seconds=t.second).total_seconds())
rollers['Duration (min:sec)'] = rollers['Duration (min:sec)'].apply(convert)
rollers.head()

#rank the rollercoasters by duration and give them points based on their ranks 
rollers_duration = rollers.dropna(subset = ['Duration (min:sec)'])
rollers['Duration Score'] = rollers_duration["Duration (min:sec)"].rank(ascending=True)
rollers_duration.sort_values(by="Duration (min:sec)", ascending = False)

rollers['Total Score']=rollers['Duration Score']+rollers['Speed Score']+rollers['Drop Score']+rollers['Construction Bonus']
rollers = rollers.sort_values(by="Total Score", ascending = False)
rollers[0:10]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Park</th>
#       <th>City/Region</th>
#       <th>City/State/Region</th>
#       <th>Country/Region</th>
#       <th>Geographic Region</th>
#       <th>Construction</th>
#       <th>Type</th>
#       <th>Status</th>
#       <th>Year/Date Opened</th>
#       <th>...</th>
#       <th>Number of Inversions</th>
#       <th>Drop (feet)</th>
#       <th>Duration (min:sec)</th>
#       <th>G Force</th>
#       <th>Vertical Angle (degrees)</th>
#       <th>Speed Score</th>
#       <th>Drop Score</th>
#       <th>Construction Bonus</th>
#       <th>Duration Score</th>
#       <th>Total Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>239</th>
#       <td>Steel Dragon 2000</td>
#       <td>Nagashima Spa Land</td>
#       <td>Nagashima</td>
#       <td>Kuwana,, Mie</td>
#       <td>Japan</td>
#       <td>Asia</td>
#       <td>Steel</td>
#       <td>Sit Down</td>
#       <td>Operating</td>
#       <td>2000.0</td>
#       <td>...</td>
#       <td>0.0</td>
#       <td>306.8</td>
#       <td>240</td>
#       <td></td>
#       <td>NaN</td>
#       <td>288.5</td>
#       <td>97.0</td>
#       <td>0</td>
#       <td>301.0</td>
#       <td>686.5</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Coaster Through the Clouds</td>
#       <td>Nanchang Wanda Theme Park</td>
#       <td>Xinjian</td>
#       <td>Nanchang, Jiangxi</td>
#       <td>China</td>
#       <td>Asia</td>
#       <td>Steel</td>
#       <td>Sit Down</td>
#       <td>Operating</td>
#       <td>2016.0</td>
#       <td>...</td>
#       <td>0.0</td>
#       <td>255.9</td>
#       <td>252</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>280.0</td>
#       <td>90.5</td>
#       <td>0</td>
#       <td>304.0</td>
#       <td>674.5</td>
#     </tr>
#     <tr>
#       <th>151</th>
#       <td>Leviathan</td>
#       <td>Canada's Wonderland</td>
#       <td>Vaughan</td>
#       <td>Onterio</td>
#       <td>Canada</td>
#       <td>North America</td>
#       <td>Steel</td>
#       <td>Sit Down</td>
#       <td>Operating</td>
#       <td>2012.0</td>
#       <td>...</td>
#       <td>0.0</td>
#       <td